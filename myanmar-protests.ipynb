# %%
import pandas as pd
import os

# %% [markdown]
# # Myanmar protests

# %% [markdown]
# ## Load data from Google sheets

# %%
path = "data/raw/myanmar-protests/"
files = sorted([f"{path}{filename}" for filename in os.listdir(path)])

files
# Out:
# ['data/raw/myanmar-protests/Myanmar 2021 - Feb 28.csv',
#  'data/raw/myanmar-protests/Myanmar 2021 - March 1-2.csv',
#  'data/raw/myanmar-protests/Myanmar 2021 - March 3.csv',
#  'data/raw/myanmar-protests/Myanmar 2021 - March 4.csv',
#  'data/raw/myanmar-protests/Myanmar 2021 - March 5.csv',
#  'data/raw/myanmar-protests/Myanmar 2021 - March 7.csv',
#  'data/raw/myanmar-protests/Myanmar 2021 - March 8.csv']

# %%
df = (
    pd.concat(
        pd.read_csv(
            file,
            usecols=[0, 3, 9, 12, 13, 14, 16, 19, 20],
            header=0,
            names=[
                "content_code",
                "source_link",
                "graphic",
                "verification_status",
                "category_1",
                "category_2",
                "event_date",
                "latitude",
                "longitude",
            ],
            parse_dates=[5],
        ).assign(filename=lambda df: file)
        for file in files
    )
    .astype({"graphic": "bool", "latitude": "float", "longitude": "float"})
    .query("verification_status == 'Verified'")
    .reset_index(drop=True)
#     .fillna({"source_link": "N/A", "category_1": "Other", "event_date": "Unknown"})
)

df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   content_code         55 non-null     object
#  1   source_link          55 non-null     object
#  2   graphic              55 non-null     bool
#  3   verification_status  55 non-null     object
#  4   category_1           55 non-null     object
#  5   category_2           10 non-null     object
#  6   event_date           55 non-null     object
#  7   latitude             55 non-null     float64
#  8   longitude            55 non-null     float64
#  9   filename             55 non-null     object
# dtypes: bool(1), float64(2), object(7)
# memory usage: 4.0+ KB
#   content_code                                        source_link  graphic  \
# 0       MMR001  https://twitter.com/hannayuri_twt/status/13659...     True
# 1       MMR002  https://twitter.com/mipnnn1910/status/13660053...     True
# 2       MMR003  https://twitter.com/Myanmar_Now_Eng/status/136...     True
# 3       MMR004  https://twitter.com/matthewfsmith/status/13658...     True
# 4       MMR005  https://www.facebook.com/khitthitnews/videos/2...    False
# 5       MMR006  https://twitter.com/wkkaung/status/13659912118...    False
# 6       MMR007  https://twitter.com/wkkaung/status/13659923915...    False
# 7       MMR008  https://twitter.com/ThomasVLinge/status/136602...     True
# 8       MMR009  https://www.youtube.com/watch?v=xgmUbOc048Y&fe...     True
# 9       MMR010  https://twitter.com/ThomasVLinge/status/136601...    False
#
#   verification_status       category_1       category_2 event_date   latitude  \
# 0            Verified           Deaths              NaN  28-Feb-21  21.968870
# 1            Verified           Deaths              NaN  28-Feb-21  21.968870
# 2            Verified           Deaths              NaN  27-Feb-21  16.825675
# 3            Verified           Deaths              NaN  27-Feb-21  16.825675
# 4            Verified  Live Ammunition              NaN  28-Feb-21  14.071170
# 5            Verified     Less-lethals              NaN  28-Feb-21  16.828289
# 6            Verified     Less-lethals              NaN  28-Feb-21  16.828364
# 7            Verified           Deaths              NaN  28-Feb-21  16.825675
# 8            Verified           Deaths  Live Ammunition  28-Feb-21  14.076131
# 9            Verified     Less-lethals              NaN  28-Feb-21  12.441568
#
#    longitude                                           filename
# 0  96.091196  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 1  96.091196  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 2  96.126747  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 3  96.126747  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 4  98.189569  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 5  96.154511  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 6  96.155626  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 7  96.126747  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 8  98.193170  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 9  98.596877  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...

# %% [markdown]
# ## Transform and write to CSV for geospatial processing

# %% [markdown]
# ### Define function to concatenate categories for map tooltips

# %%
def tooltip(categories_list):
    return ", ".join(categories_list).capitalize()

# %%
df_geo = df.copy().assign(
    categories_list_nans=lambda df: df[["category_1", "category_2"]].values.tolist(),
    categories_list=lambda df: df["categories_list_nans"].apply(
        lambda x: sorted([d for d in x if str(d) != "nan"])
    ),
    tooltip = lambda df: df["categories_list"].apply(lambda x: tooltip(x))
)

df_geo.info()
df_geo.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   content_code          55 non-null     object
#  1   source_link           55 non-null     object
#  2   graphic               55 non-null     bool
#  3   verification_status   55 non-null     object
#  4   category_1            55 non-null     object
#  5   category_2            10 non-null     object
#  6   event_date            55 non-null     object
#  7   latitude              55 non-null     float64
#  8   longitude             55 non-null     float64
#  9   filename              55 non-null     object
#  10  categories_list_nans  55 non-null     object
#  11  categories_list       55 non-null     object
#  12  tooltip               55 non-null     object
# dtypes: bool(1), float64(2), object(10)
# memory usage: 5.3+ KB
#   content_code                                        source_link  graphic  \
# 0       MMR001  https://twitter.com/hannayuri_twt/status/13659...     True
# 1       MMR002  https://twitter.com/mipnnn1910/status/13660053...     True
# 2       MMR003  https://twitter.com/Myanmar_Now_Eng/status/136...     True
# 3       MMR004  https://twitter.com/matthewfsmith/status/13658...     True
# 4       MMR005  https://www.facebook.com/khitthitnews/videos/2...    False
# 5       MMR006  https://twitter.com/wkkaung/status/13659912118...    False
# 6       MMR007  https://twitter.com/wkkaung/status/13659923915...    False
# 7       MMR008  https://twitter.com/ThomasVLinge/status/136602...     True
# 8       MMR009  https://www.youtube.com/watch?v=xgmUbOc048Y&fe...     True
# 9       MMR010  https://twitter.com/ThomasVLinge/status/136601...    False
#
#   verification_status       category_1       category_2 event_date   latitude  \
# 0            Verified           Deaths              NaN  28-Feb-21  21.968870
# 1            Verified           Deaths              NaN  28-Feb-21  21.968870
# 2            Verified           Deaths              NaN  27-Feb-21  16.825675
# 3            Verified           Deaths              NaN  27-Feb-21  16.825675
# 4            Verified  Live Ammunition              NaN  28-Feb-21  14.071170
# 5            Verified     Less-lethals              NaN  28-Feb-21  16.828289
# 6            Verified     Less-lethals              NaN  28-Feb-21  16.828364
# 7            Verified           Deaths              NaN  28-Feb-21  16.825675
# 8            Verified           Deaths  Live Ammunition  28-Feb-21  14.076131
# 9            Verified     Less-lethals              NaN  28-Feb-21  12.441568
#
#    longitude                                           filename  \
# 0  96.091196  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 1  96.091196  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 2  96.126747  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 3  96.126747  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 4  98.189569  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 5  96.154511  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 6  96.155626  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 7  96.126747  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 8  98.193170  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
# 9  98.596877  data/raw/myanmar-protests/Myanmar 2021 - Feb 2...
#
#         categories_list_nans            categories_list  \
# 0              [Deaths, nan]                   [Deaths]
# 1              [Deaths, nan]                   [Deaths]
# 2              [Deaths, nan]                   [Deaths]
# 3              [Deaths, nan]                   [Deaths]
# 4     [Live Ammunition, nan]          [Live Ammunition]
# 5        [Less-lethals, nan]             [Less-lethals]
# 6        [Less-lethals, nan]             [Less-lethals]
# 7              [Deaths, nan]                   [Deaths]
# 8  [Deaths, Live Ammunition]  [Deaths, Live Ammunition]
# 9        [Less-lethals, nan]             [Less-lethals]
#
#                    tooltip
# 0                   Deaths
# 1                   Deaths
# 2                   Deaths
# 3                   Deaths
# 4          Live ammunition
# 5             Less-lethals
# 6             Less-lethals
# 7                   Deaths
# 8  Deaths, live ammunition
# 9             Less-lethals

# %%
df_geo[
    [
        "content_code",
        "source_link",
        "graphic",
        "event_date",
        "latitude",
        "longitude",
#         "filename",
        "tooltip",
    ]
].to_csv("data/processed/myanmar-protests-map.csv", index=False)
